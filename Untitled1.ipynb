# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
website = 'https://www.yelp.com/search?find_desc=Restaurants&find_loc=New%20York%2C%20NY'

# %%
response = requests.get(website)

# %%
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
result_container = soup.find_all('div', {'class': 'container__09f24__sxa9- hoverable__09f24__3HkY2 margin-t3__09f24__hHZsm margin-b3__09f24__3h89A padding-t3__09f24__1VTAn padding-r3__09f24__11Xv2 padding-b3__09f24__2I83c padding-l3__09f24__1JEx9 border--top__09f24__37VAs border--right__09f24__Z9jGU border--bottom__09f24__3lElq border--left__09f24__akfOa border-color--default__09f24__3Epto'})

# %%
result_container
# Out:
# [<div class="container__09f24__sxa9- hoverable__09f24__3HkY2 margin-t3__09f24__hHZsm margin-b3__09f24__3h89A padding-t3__09f24__1VTAn padding-r3__09f24__11Xv2 padding-b3__09f24__2I83c padding-l3__09f24__1JEx9 border--top__09f24__37VAs border--right__09f24__Z9jGU border--bottom__09f24__3lElq border--left__09f24__akfOa border-color--default__09f24__3Epto"><div class="border-color--default__09f24__3Epto"><div class="arrange__09f24__1Vghi border-color--default__09f24__3Epto"><div class="arrange-unit__09f24__eFC_S border-color--default__09f24__3Epto"><div class="border-color--default__09f24__3Epto"><div aria-hidden="false" class="display--inline-block__09f24__3SvIn margin-r3__09f24__3HTZd border-color--default__09f24__3Epto"><div class="border-color--default__09f24__3Epto"><div class="container__09f24__1bcr9 dontTriggerCardClick__09f24__1UCg1 container--responsive__09f24__25Lh- container--serpia--responsive__09f24__A6moK container__09f24__8llqV undefined border-color--default__09f24__3Ept
# ...

# %%
len(result_container)
# Out:
# 10

# %%
# we combine url part no.1 with url part no.2 in order to get the absolute url

url_part_1 = 'https://www.yelp.com/'

# %%
url_part_2 = []

#loop through the results

for item in result_container:
    #loop through links
    for link in item.find_all('a'):
            url_part_2.append(link.get('href'))

# %%
url_part_2
# Out:
# ['/biz/thursday-kitchen-new-york?osq=Restaurants',
#  '/biz/thursday-kitchen-new-york?osq=Restaurants',
#  '/search?cflt=korean&find_loc=New+York%2C+NY',
#  '/search?cflt=newamerican&find_loc=New+York%2C+NY',
#  '/search?cflt=tapasmallplates&find_loc=New+York%2C+NY',
#  '/biz/thursday-kitchen-new-york?hrid=oUEEuhOZ8BcDvGpIRcxw4g&osq=Restaurants',
#  '/biz/am%C3%A9lie-new-york?osq=Restaurants',
#  '/biz/am%C3%A9lie-new-york?osq=Restaurants',
#  '/search?cflt=french&find_loc=New+York%2C+NY',
#  '/search?cflt=wine_bars&find_loc=New+York%2C+NY',
#  '/biz/am%C3%A9lie-new-york?hrid=nfFT_yYq6bEtAoZjyc7L0w&osq=Restaurants',
#  '/biz/the-cabin-nyc-new-york-2?osq=Restaurants',
#  '/biz/the-cabin-nyc-new-york-2?osq=Restaurants',
#  '/search?cflt=newamerican&find_loc=New+York%2C+NY',
#  '/search?cflt=cocktailbars&find_loc=New+York%2C+NY',
#  '/search?cflt=breakfast_brunch&find_loc=New+York%2C+NY',
#  '/biz/the-cabin-nyc-new-york-2?hrid=3lIAv4rVOJUKQ5Yf3rXUjw&osq=Restaurants',
# ...

# %%
url_part_2_ = []

for link in url_part_2:
    if link.has_attr('osq=Restaurants'):
        url_part_2_.append(link)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-4ca1e5e0f74b> in <module>
#       2
#       3 for link in url_part_2:
# ----> 4     if link.has_attr('osq=Restaurants'):
#       5         url_part_2_.append(link)
#
# AttributeError: 'str' object has no attribute 'has_attr'
